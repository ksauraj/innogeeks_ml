# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("xAPI-Edu-Data.csv")
df
plt.style.use('ggplot')

# %%
df.describe()
# Out:
#        raisedhands  VisITedResources  AnnouncementsView  Discussion
# count   480.000000        480.000000         480.000000  480.000000
# mean     46.775000         54.797917          37.918750   43.283333
# std      30.779223         33.080007          26.611244   27.637735
# min       0.000000          0.000000           0.000000    1.000000
# 25%      15.750000         20.000000          14.000000   20.000000
# 50%      50.000000         65.000000          33.000000   39.000000
# 75%      75.000000         84.000000          58.000000   70.000000
# max     100.000000         99.000000          98.000000   99.000000

# %%
df.isnull().sum()
# Out:
# gender                      0
# NationalITy                 0
# PlaceofBirth                0
# StageID                     0
# GradeID                     0
# SectionID                   0
# Topic                       0
# Semester                    0
# Relation                    0
# raisedhands                 0
# VisITedResources            0
# AnnouncementsView           0
# Discussion                  0
# ParentAnsweringSurvey       0
# ParentschoolSatisfaction    0
# StudentAbsenceDays          0
# Class                       0
# dtype: int64

# %%
sns.pairplot(data=df)

# %%
df['NationalITy'].value_counts()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    480 non-null    object
#  1   NationalITy               480 non-null    object
#  2   PlaceofBirth              480 non-null    object
#  3   StageID                   480 non-null    object
#  4   GradeID                   480 non-null    object
#  5   SectionID                 480 non-null    object
#  6   Topic                     480 non-null    object
#  7   Semester                  480 non-null    object
#  8   Relation                  480 non-null    object
#  9   raisedhands               480 non-null    int64
#  10  VisITedResources          480 non-null    int64
#  11  AnnouncementsView         480 non-null    int64
#  12  Discussion                480 non-null    int64
# ...

# %%
sns.barplot(df['NationalITy'].value_counts(), width=0.6, orient="h")
# Out:
# <Axes: xlabel='count', ylabel='NationalITy'>

# %%
numericals_col = df.select_dtypes(include=['number'])
correlation_matrix = numericals_col.corr()
correlation_matrix
# Out:
#                    raisedhands  VisITedResources  AnnouncementsView
# raisedhands           1.000000          0.691572           0.643918  \
# VisITedResources      0.691572          1.000000           0.594500
# AnnouncementsView     0.643918          0.594500           1.000000
# Discussion            0.339386          0.243292           0.417290
#
#                    Discussion
# raisedhands          0.339386
# VisITedResources     0.243292
# AnnouncementsView    0.417290
# Discussion           1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 480 entries, 0 to 479
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   gender                    480 non-null    object
#  1   NationalITy               480 non-null    object
#  2   PlaceofBirth              480 non-null    object
#  3   StageID                   480 non-null    object
#  4   GradeID                   480 non-null    object
#  5   SectionID                 480 non-null    object
#  6   Topic                     480 non-null    object
#  7   Semester                  480 non-null    object
#  8   Relation                  480 non-null    object
#  9   raisedhands               480 non-null    int64
#  10  VisITedResources          480 non-null    int64
#  11  AnnouncementsView         480 non-null    int64
#  12  Discussion                480 non-null    int64
# ...

# %%
sns.lineplot(data=df, x='VisITedResources', y='raisedhands')
# Out:
# <Axes: xlabel='VisITedResources', ylabel='raisedhands'>

# %%
sau = sns.countplot(data=df[0:80], x='VisITedResources', orient='v' )
sau.set_xticklabels(sau.get_xticklabels(), rotation=40, ha="right")
# Out:
# /tmp/ipykernel_2464/3085519395.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   sau.set_xticklabels(sau.get_xticklabels(), rotation=40, ha="right")
# [Text(0, 0, '0'),
#  Text(1, 0, '1'),
#  Text(2, 0, '2'),
#  Text(3, 0, '3'),
#  Text(4, 0, '4'),
#  Text(5, 0, '5'),
#  Text(6, 0, '6'),
#  Text(7, 0, '7'),
#  Text(8, 0, '10'),
#  Text(9, 0, '11'),
#  Text(10, 0, '12'),
#  Text(11, 0, '13'),
#  Text(12, 0, '14'),
#  Text(13, 0, '15'),
#  Text(14, 0, '16'),
#  Text(15, 0, '19'),
#  Text(16, 0, '20'),
#  Text(17, 0, '21'),
#  Text(18, 0, '22'),
#  Text(19, 0, '25'),
#  Text(20, 0, '30'),
#  Text(21, 0, '33'),
#  Text(22, 0, '35'),
#  Text(23, 0, '39'),
#  Text(24, 0, '40'),
#  Text(25, 0, '50'),
#  Text(26, 0, '54'),
#  Text(27, 0, '60'),
#  Text(28, 0, '69'),
#  Text(29, 0, '70'),
#  Text(30, 0, '75'),
#  Text(31, 0, '80'),
#  Text(32, 0, '85'),
#  Text(33, 0, '88'),
#  Text(34, 0, '90')]

# %%
sns.barplot(data = df["StageID"].value_counts())
# Out:
# <Axes: xlabel='StageID', ylabel='count'>

# %%
fig, axarr = plt.subplots(2,2, figsize=(10,10))
sns.countplot(x='Class', data=df, ax=axarr[0,0], order=['L', 'M', 'H'])
sns.countplot(x='gender', data=df, ax=axarr[0,1], order=['M', 'F'])
sns.countplot(x='StageID', data=df, ax=axarr[1,0])
sns.countplot(x='Semester', data=df, ax=axarr[1,1])
# Out:
# <Axes: xlabel='Semester', ylabel='count'>
